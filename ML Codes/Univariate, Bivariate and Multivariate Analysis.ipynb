# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/users/siddharthsmac/downloads/IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_setosa = df.loc[df['species']=='Iris-setosa']

# %%
df_virginica = df.loc[df['species']=='Iris-virginica']
df_versicolor = df.loc[df['species']=='Iris-versicolor']

# %%
plt.plot(df_setosa['petal_length'], np.zeros_like(df_setosa['petal_length']),'o')
plt.plot(df_virginica['petal_length'], np.zeros_like(df_virginica['petal_length']),'o')
plt.plot(df_versicolor['petal_length'], np.zeros_like(df_versicolor['petal_length']),'o')
plt.xlabel('Petal length')
plt.show()

# %%
sns.FacetGrid(df, hue = 'species', size = 5).map(plt.scatter, 'petal_length', 'sepal_width').add_legend();
# Out:
# /Users/siddharthsmac/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, hue = 'species', size = 3)
# Out:
# /Users/siddharthsmac/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df1 = pd.read_csv('/users/siddharthsmac/downloads/covid_country_wise.csv')

# %%
df1.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0    Afghanistan      20917   369.0       2171  18377.0        575
# 1        Albania       1263    34.0        945    284.0         17
# 2        Algeria      10265   715.0       6799   2751.0        111
# 3        Andorra        852    51.0        751     50.0          0
# 4         Angola         92     4.0         38     50.0          1
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          12            296                1.76                  10.38
# 1           0              7                2.69                  74.82
# 2           8             82                6.97                  66.23
# 3           0              7                5.99                  88.15
# 4           0             14                4.35                  41.30
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                   17.00                15750           5167
# ...

# %%
Europe = df1.loc[df1['WHO Region']=='Europe']
Europe.head()
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 1         Albania       1263    34.0        945   284.0         17
# 3         Andorra        852    51.0        751    50.0          0
# 7         Armenia      13325   211.0       4099  9015.0        195
# 9         Austria      16968   672.0      15839   457.0         66
# 10     Azerbaijan       7876    93.0       4377  3406.0        323
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 1            0              7                2.69                  74.82
# 3            0              7                5.99                  88.15
# 7           11             85                1.58                  30.76
# 9            0             46                3.96                  93.35
# 10           5            228                1.18                  55.57
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
America = df1.loc[df1['WHO Region']=='Americas']
Asia = df1.loc[df1['WHO Region']=='South-East Asia']

# %%
plt.plot(Europe['Confirmed'], np.zeros_like(Europe['Confirmed']),'o')
plt.plot(America['Confirmed'], np.zeros_like(America['Confirmed']),'o')
plt.plot(Asia['Confirmed'], np.zeros_like(Asia['Confirmed']),'o')
plt.xlabel('Confirmed')
# Out:
# Text(0.5, 0, 'Confirmed')

# %%
sns.FacetGrid(df1, hue = 'WHO Region', size = 7).map(plt.scatter, 'Confirmed', 'Deaths').add_legend();
# Out:
# /Users/siddharthsmac/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df1, hue = 'WHO Region')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-51e5f2f07f91> in <module>
# ----> 1 sns.pairplot(df1, hue = 'WHO Region')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119             diag_kws.setdefault("shade", True)
# ...

# %%
z1 = df.iloc[:,[1,2,3]]

# %%
z.head
